# %%
import plot_grid_compare as pgc
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from MIST_codes.plot_routine import read_mist_models as rmm
# %matplotlib inline

print(os.path.isdir(os.getcwd()))
#/MIST_grids/MIST_v1.0/output/feh_p0.00_afe_p0.0_vvcrit0.0/'))
# Out:
# True

# %%
dataf = [None]#['/n/home12/sgossage/match2.6_updated/MIST/Praesepe/photometry/praesepe_vanlTIGS_TychoBV.phot']

pgc.compare_iso([0.15, 0.15],[0.0, 0.0],[8.7, 8.7], [('Tycho_B', 'Tycho_V')], dmod=[3.36, 6.24], ebv=[0.001, 0.09],
                xlim=[-0.5, 1.0], ylim = [12,2], griddx=0.10, griddy=0.20, dataf = dataf)

img = mpimg.imread(os.path.join(os.getcwd(), 'plots', 'IsoCMD_comparison.png'))
plt.figure(figsize=(24,14))
plt.imshow(img)
plt.axis('off')
# Out:
# /home/seth/Research/MIST/MISTout
#
# Extending option: gravdark_i = 0.0 to all grids.
#
# The .cmd file "/home/seth/Research/MIST/MISTout/feh_p0.15_afe_p0.0_vvcrit0.0/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.0_full.iso.cmd" already exists...
# Desired Av = 0.003 matches existing Av = 0.003; the existing .cmd file will be used.
# Reading in: /home/seth/Research/MIST/MISTout/feh_p0.15_afe_p0.0_vvcrit0.0/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.0_full.iso.cmd
# The .cmd file "/home/seth/Research/MIST/MISTout/feh_p0.15_afe_p0.0_vvcrit0.0/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.0_full.iso.cmd" already exists...
# Desired Av = 0.279 does not match existing Av = 0.003; creating a new .cmd file...
#
# Creating .cmd file from /home/seth/Research/MIST/MISTout/feh_p0.15_afe_p0.0_vvcrit0.0/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.0_full.iso (log10 age range 7.000000 to 10.000000)...
#
# ...

# %%
dataf = ['/n/home12/sgossage/match2.6_updated/MIST/Praesepe/photometry/praesepe_vanlTIGS_TychoBV.phot']

pgc.compare_iso([0.15, 0.15],[0.4, 0.4],[8.7, 8.7], [('Tycho_B', 'Tycho_V')], dmod=[6.24, 6.24], ebv=[0.09, 0.09],
                xlim=[0.0, 1.0], ylim = [12,4], griddx=0.10, griddy=0.20, dataf = dataf, gravdark_on = [True, False])

img = mpimg.imread(os.path.join(os.getcwd(), 'plots', 'IsoCMD_comparison.png'))
plt.figure(figsize=(24,14))

plt.imshow(img)
plt.axis('off')
# Out:
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.15_afe_p0.0_vvcrit0.4/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.4_full.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.15_afe_p0.0_vvcrit0.4/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.4_full.iso.cmd
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.15_afe_p0.0_vvcrit0.4/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.4_full.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.15_afe_p0.0_vvcrit0.4/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.4_full.iso.cmd
# (-0.5, 5399.5, 3599.5, -0.5)

# %%
#dataf = #['/n/home12/sgossage/match2.6_updated/MIST/Praesepe/photometry/praesepe_vanlTIGS_TychoBV.phot']

pgc.compare_iso([0.30, 0.30],[0.4, 0.4],[8.7, 8.7], [('Tycho_B', 'Tycho_V')], dmod=[3.36, 3.36], ebv=[0.001, 0.001],
                xlim=[-0.5, 1.0], ylim = [12,2], griddx=0.10, griddy=0.20, extra=[None,'amDmix0.066'])

img = mpimg.imread(os.path.join(os.getcwd(), 'plots', 'IsoCMD_comparison.png'))
plt.figure(figsize=(24,14))
plt.imshow(img)
plt.axis('off')
# Out:
# Extending option: gravdark_on = False to all grids.
#
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.30_afe_p0.0_vvcrit0.4/isochrones/MIST_v1.0_feh_p0.30_afe_p0.0_vvcrit0.4_full.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.30_afe_p0.0_vvcrit0.4/isochrones/MIST_v1.0_feh_p0.30_afe_p0.0_vvcrit0.4_full.iso.cmd
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.30_afe_p0.0_vvcrit0.4_amDmix0.066/isochrones/MIST_v1.0_feh_p0.30_afe_p0.0_vvcrit0.4_amDmix0.066_full.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.30_afe_p0.0_vvcrit0.4_amDmix0.066/isochrones/MIST_v1.0_feh_p0.30_afe_p0.0_vvcrit0.4_amDmix0.066_full.iso.cmd
# (-0.5, 3599.5, 2399.5, -0.5)

# %%
#dataf = #['/n/home12/sgossage/match2.6_updated/MIST/Praesepe/photometry/praesepe_vanlTIGS_TychoBV.phot']

pgc.compare_iso([0.15, 0.15],[0.4, 0.4],[8.7, 8.7], [('Tycho_B', 'Tycho_V')], dmod=[3.36, 3.36], ebv=[0.001, 0.001],
                xlim=[-0.2, 0.2], ylim = [6,2], griddx=0.10, griddy=0.20, extra=[None,'amDmix0.066'])

img = mpimg.imread(os.path.join(os.getcwd(), 'plots', 'IsoCMD_comparison.png'))
plt.figure(figsize=(24,14))
plt.imshow(img)
plt.axis('off')
# Out:
# Extending option: gravdark_on = False to all grids.
#
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.15_afe_p0.0_vvcrit0.4/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.4_full.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.15_afe_p0.0_vvcrit0.4/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.4_full.iso.cmd
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.15_afe_p0.0_vvcrit0.4_amDmix0.066/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.4_amDmix0.066_full.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.15_afe_p0.0_vvcrit0.4_amDmix0.066/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.4_amDmix0.066_full.iso.cmd
# (-0.5, 3599.5, 2399.5, -0.5)

# %%
rmm.ISOCMD
# Out:
# <class MIST_codes.plot_routine.read_mist_models.ISOCMD at 0x7f90cd176ef0>
