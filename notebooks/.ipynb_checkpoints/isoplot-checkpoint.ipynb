# %%
from MIST_codes.scripts import read_mist_models as rmm
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-e3b80ae30a50> in <module>()
# ----> 1 from MIST_codes.scripts import read_mist_models as rmm
#
# /home/seth/Programs/anaconda2/lib/python2.7/site-packages/MIST_codes/scripts/__init__.py in <module>()
#       8     __MAKE_ISOCH_DIR__ = os.environ['ISO_DIR']
#       9 except KeyError:
# ---> 10     raise ImportError("Check that you have the MESAWORK_DIR, MIST_GRID_DIR, MIST_CODE_DIR, STORE_DIR, and ISO_DIR environment variables set")
#
# ImportError: Check that you have the MESAWORK_DIR, MIST_GRID_DIR, MIST_CODE_DIR, STORE_DIR, and ISO_DIR environment variables set

# %%
iso = rmm.ISOCMD(0.00, 0.4, ebv=0.001)
# Out:
# /home/seth/Research/MIST/MISTout
# feh_p0.00_afe_p0.0_vvcrit0.4
# /home/seth/Research/MIST/MISTout/feh_p0.00_afe_p0.0_vvcrit0.4
# The .cmd file "/home/seth/Research/MIST/MISTout/feh_p0.00_afe_p0.0_vvcrit0.4/isochrones/MIST_v1.0_feh_p0.00_afe_p0.0_vvcrit0.4_full.iso.cmd" already exists...
# Desired Av = 0.003 matches existing Av = 0.003; the existing .cmd file will be used.
# Reading in: /home/seth/Research/MIST/MISTout/feh_p0.00_afe_p0.0_vvcrit0.4/isochrones/MIST_v1.0_feh_p0.00_afe_p0.0_vvcrit0.4_full.iso.cmd

# %%
iso.set_isodata(8.00,'Tycho_V','Tycho_B')

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(16,9))
ax = fig.add_subplot(111)

iso.set_isodata(8.00,'Tycho_V','Tycho_B')
iso.isoplot(ax)
iso.set_isodata(8.20,'Tycho_V','Tycho_B')
iso.isoplot(ax,shade=1.0)

plt.show()

# %%
iso = rmm.ISOCMD(0.30, 0.4, ebv=0.001,exttag='HB')
# Out:
# /home/seth/Research/MIST/MISTout
# feh_p0.30_afe_p0.0_vvcrit0.4
# /home/seth/Research/MIST/MISTout/feh_p0.30_afe_p0.0_vvcrit0.4_HB
# The .cmd file "/home/seth/Research/MIST/MISTout/feh_p0.30_afe_p0.0_vvcrit0.4_HB/isochrones/MIST_v1.0_feh_p0.30_afe_p0.0_vvcrit0.4_HB_full.iso.cmd" already exists...
# Desired Av = 0.003 matches existing Av = 0.003; the existing .cmd file will be used.
# Reading in: /home/seth/Research/MIST/MISTout/feh_p0.30_afe_p0.0_vvcrit0.4_HB/isochrones/MIST_v1.0_feh_p0.30_afe_p0.0_vvcrit0.4_HB_full.iso.cmd

# %%
fig = plt.figure(figsize=(16,9))
ax = fig.add_subplot(111)

iso.set_isodata(7.50,'Tycho_V','Tycho_B')
iso.isoplot(ax)

plt.show()
