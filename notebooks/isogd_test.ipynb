# %%
import matplotlib.image as mpimg
import plot_grid_compare as pgc
from plot_routine import read_mist_models as rmm
import os
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages


# %matplotlib inline
print(os.getcwd())
os.chdir(os.environ['MIST_CODE_DIR'])
# Out:
# /home/seth/Programs/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/seth/Research/MIST/MIST_codes

# %%
rots = [0.0]
num_isos=len(rots)
fehs = [0.15]*num_isos
ages = [8.8]*num_isos
angs = [0.0]
#datapath = ['/n/home12/sgossage/match2.6_updated/MIST/Hyades/photometry/hyades_debruTIGS_TychoBV.phot']#,
            #'/n/home12/sgossage/match2.6_updated/MIST/Hyades/photometry/hyades_kopytova16_2MASSJK.phot']
filters = [('Tycho_B','Tycho_V')]#, ('2MASS_J', '2MASS_Ks')]
pgc.compare_iso(fehs, rots, ages, filters, dataf=[None], dmod=[3.33], ebv = [0.0032], tbins=[None],gravdark_i=angs, ylim=[8,2], xlim=[-0.1,1.7])
img = mpimg.imread(os.path.join(os.getcwd(), 'plots', 'IsoCMD_comparison.png'))
plt.figure(figsize=(24,14))
plt.imshow(img)
plt.axis('off')
# Out:
# The .cmd file "/home/seth/Research/MIST/MISTout/feh_p0.15_afe_p0.0_vvcrit0.0/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.0_full_gdark45.0_gdark90.0.iso.cmd" already exists...
# Desired Av = 0.010 matches existing Av = 0.010; the existing .cmd file will be used.
# Reading in: /home/seth/Research/MIST/MISTout/feh_p0.15_afe_p0.0_vvcrit0.0/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.0_full_gdark45.0_gdark90.0.iso.cmd
# (-0.5, 3599.5, 2399.5, -0.5)
