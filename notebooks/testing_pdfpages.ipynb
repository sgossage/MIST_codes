# %%
import matplotlib.image as mpimg
import plot_grid_compare as pgc
from plot_routine import read_mist_models as rmm
import os
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages


# %matplotlib inline
print(os.getcwd())
os.chdir(os.environ['MIST_CODE_DIR'])
# Out:
# /n/home12/sgossage/.conda/envs/ANA_192/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /n/home12/sgossage/MIST_codes

# %%
rots = [0.0, 0.6, 0.6, 0.0]
num_isos=len(rots)
fehs = [0.0, 0.0, 0.30, 0.0]
ages = [8.2, 8.2, 8.2, 8.13]

pts, fig = pgc.compare_iso(fehs, rots, ages, [('Tycho_B','Tycho_V')], 
                dataf = ['/n/home12/sgossage/match2.6_updated/MIST/Pleiades/photometry/pleiades_vanlTIGS_TychoBV.phot'],
                pltmass=False, geneva_on = False, ylim= [8, 2], xlim = [], ebv = [0.034], dmod = [5.97])

img = mpimg.imread(os.path.join(os.getcwd(), 'plots', 'IsoCMD_comparison.png'))
plt.figure(figsize=(24,14))
plt.imshow(img)
plt.axis('off')
# Out:
# Extending option: gravdark_on = False to all grids.
#
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.00_afe_p0.0_vvcrit0.0/isochrones/MIST_v1.0_feh_p0.00_afe_p0.0_vvcrit0.0_full.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.00_afe_p0.0_vvcrit0.0/isochrones/MIST_v1.0_feh_p0.00_afe_p0.0_vvcrit0.0_full.iso.cmd
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.00_afe_p0.0_vvcrit0.6/isochrones/MIST_v1.0_feh_p0.00_afe_p0.0_vvcrit0.6_full.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.00_afe_p0.0_vvcrit0.6/isochrones/MIST_v1.0_feh_p0.00_afe_p0.0_vvcrit0.6_full.iso.cmd
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.30_afe_p0.0_vvcrit0.6/isochrones/MIST_v1.0_feh_p0.30_afe_p0.0_vvcrit0.6_full.iso (log10 age range 7.000000 to 10.000000)...
# ...

# %%
with PdfPages('testpdf.pdf') as pdf:
    pdf.savefig(fig)
