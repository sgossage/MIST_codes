# %%
import matplotlib.image as mpimg
import plot_grid_compare as pgc
from plot_routine import read_mist_models as rmm
import os
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages


# %matplotlib inline
print(os.getcwd())
os.chdir(os.environ['MIST_CODE_DIR'])
# Out:
# /n/home12/sgossage/.conda/envs/ANA_192/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /n/home12/sgossage/MIST_codes

# %% [markdown]
# # Pleiades TychoBV

# %%
rots = [0.5]
num_isos=len(rots)
fehs = [0.08]
ages = [8.08]
datapath = ['/n/home12/sgossage/match2.6_updated/MIST/Pleiades/photometry/pleiades_vanlTIGS_TychoBV.phot']#,
            #'/n/home12/sgossage/match2.6_updated/MIST/Hyades/photometry/hyades_kopytova16_2MASSJK.phot']
filters = [('Tycho_B','Tycho_V')]#, ('2MASS_J', '2MASS_Ks')]
pgc.compare_iso(fehs, rots, ages, filters, dataf=datapath, dmod=[5.64], ebv = [0.034], ylim=[8,2], xlim=[-0.5,2])
img = mpimg.imread(os.path.join(os.getcwd(), 'plots', 'IsoCMD_comparison.png'))
plt.figure(figsize=(24,14))
plt.imshow(img)
plt.axis('off')
# Out:
# The created .iso file, /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.08_afe_p0.0_vvcrit0.5_interp.iso, has age range: 7.000000 to 10.000000 in log10 age.
#
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.08_afe_p0.0_vvcrit0.5_interp.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.08_afe_p0.0_vvcrit0.5_interp.iso.cmd
# (-0.5, 3599.5, 2399.5, -0.5)

# %% [markdown]
# # Pleiades 2MASSJK

# %%
rots = [0.0]
num_isos=len(rots)
fehs = [0.11]
ages = [8.56]
datapath = ['/n/home12/sgossage/match2.6_updated/MIST/Pleiades/photometry/pleiades_vanlTIGS_2MASSJK.phot']#,
            #'/n/home12/sgossage/match2.6_updated/MIST/Hyades/photometry/hyades_kopytova16_2MASSJK.phot']
filters = [('2MASS_J', '2MASS_Ks')]
pgc.compare_iso(fehs, rots, ages, filters, dataf=datapath, dmod=[5.64], ebv = [0.034], ylim=[8,4], xlim=[-0.4,1], griddx=0.05, griddy=0.2)
img = mpimg.imread(os.path.join(os.getcwd(), 'plots', 'IsoCMD_comparison.png'))
plt.figure(figsize=(24,14))
plt.imshow(img)
plt.axis('off')
# Out:
# The created .iso file, /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.11_afe_p0.0_vvcrit0.0_interp.iso, has age range: 7.000000 to 10.000000 in log10 age.
#
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.11_afe_p0.0_vvcrit0.0_interp.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.11_afe_p0.0_vvcrit0.0_interp.iso.cmd
# (-0.5, 3599.5, 2399.5, -0.5)

# %%
rots = [0.0]
num_isos=len(rots)
fehs = [0.11]
ages = [8.56]
datapath = ['/n/home12/sgossage/match2.6_updated/MIST/Pleiades/photometry/pleiades_stauffer07_2MASSJK.phot']#,
            #'/n/home12/sgossage/match2.6_updated/MIST/Hyades/photometry/hyades_kopytova16_2MASSJK.phot']
filters = [('2MASS_J', '2MASS_Ks')]
pgc.compare_iso(fehs, rots, ages, filters, dataf=datapath, dmod=[5.64], ebv = [0.034], ylim=[8,4], xlim=[-0.4,1])
img = mpimg.imread(os.path.join(os.getcwd(), 'plots', 'IsoCMD_comparison.png'))
plt.figure(figsize=(24,14))
plt.imshow(img)
plt.axis('off')
# Out:
# The created .iso file, /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.11_afe_p0.0_vvcrit0.0_interp.iso, has age range: 7.000000 to 10.000000 in log10 age.
#
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.11_afe_p0.0_vvcrit0.0_interp.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.11_afe_p0.0_vvcrit0.0_interp.iso.cmd
# (-0.5, 3599.5, 2399.5, -0.5)

# %% [markdown]
# # Praesepe Tycho BV

# %%
rots = [0.4]
num_isos=len(rots)
fehs = [0.24]
ages = [8.77]
datapath = ['/n/home12/sgossage/match2.6_updated/MIST/Praesepe/photometry/praesepe_vanlTIGS_TychoBV.phot']#,
            #'/n/home12/sgossage/match2.6_updated/MIST/Hyades/photometry/hyades_kopytova16_2MASSJK.phot']
filters = [('Tycho_B','Tycho_V')]#, ('2MASS_J', '2MASS_Ks')]
pgc.compare_iso(fehs, rots, ages, filters, dataf=datapath, dmod=[6.26], ebv = [0.027], ylim=[9,5], xlim=[-0.3,1.6])
img = mpimg.imread(os.path.join(os.getcwd(), 'plots', 'IsoCMD_comparison.png'))
plt.figure(figsize=(24,14))
plt.imshow(img)
plt.axis('off')
# Out:
# The created .iso file, /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.24_afe_p0.0_vvcrit0.4_interp.iso, has age range: 7.000000 to 10.000000 in log10 age.
#
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.24_afe_p0.0_vvcrit0.4_interp.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.24_afe_p0.0_vvcrit0.4_interp.iso.cmd
# (-0.5, 3599.5, 2399.5, -0.5)

# %%
rots = [0.4]
num_isos=len(rots)
fehs = [0.20]
ages = [8.66]
datapath = ['/n/home12/sgossage/match2.6_updated/MIST/Praesepe/photometry/praesepe_vanlTIGS_2MASSJK.phot']#,
            #'/n/home12/sgossage/match2.6_updated/MIST/Hyades/photometry/hyades_kopytova16_2MASSJK.phot']
filters = [('2MASS_J', '2MASS_Ks')]
pgc.compare_iso(fehs, rots, ages, filters, dataf=datapath, dmod=[6.26], ebv = [0.027], ylim=[9,4.5], xlim=[-0.4,1])
img = mpimg.imread(os.path.join(os.getcwd(), 'plots', 'IsoCMD_comparison.png'))
plt.figure(figsize=(24,14))
plt.imshow(img)
plt.axis('off')
# Out:
# The created .iso file, /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.20_afe_p0.0_vvcrit0.4_interp.iso, has age range: 7.000000 to 10.000000 in log10 age.
#
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.20_afe_p0.0_vvcrit0.4_interp.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.20_afe_p0.0_vvcrit0.4_interp.iso.cmd
# (-0.5, 3599.5, 2399.5, -0.5)

# %%
rots = [0.4]
num_isos=len(rots)
fehs = [0.20]
ages = [8.66]
datapath = ['/n/home12/sgossage/match2.6_updated/MIST/Praesepe/photometry/praesepe_wang14_2MASSJK.phot']#,
            #'/n/home12/sgossage/match2.6_updated/MIST/Hyades/photometry/hyades_kopytova16_2MASSJK.phot']
filters = [('2MASS_J', '2MASS_Ks')]
pgc.compare_iso(fehs, rots, ages, filters, dataf=datapath, dmod=[6.26], ebv = [0.027], ylim=[9,4.5], xlim=[-0.4,1])
img = mpimg.imread(os.path.join(os.getcwd(), 'plots', 'IsoCMD_comparison.png'))
plt.figure(figsize=(24,14))
plt.imshow(img)
plt.axis('off')
# Out:
# The created .iso file, /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.20_afe_p0.0_vvcrit0.4_interp.iso, has age range: 7.000000 to 10.000000 in log10 age.
#
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.20_afe_p0.0_vvcrit0.4_interp.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.20_afe_p0.0_vvcrit0.4_interp.iso.cmd
# (-0.5, 3599.5, 2399.5, -0.5)

# %% [markdown]
# # Hyades Tycho BV

# %%
rots = [0.5, 0.5, 0.5]
num_isos=len(rots)
fehs = [0.24, 0.15, 0.1]
ages = [8.75, 8.75, 8.75]
datapath = ['/n/home12/sgossage/match2.6_updated/MIST/Hyades/photometry/hyades_debruTIGS_TychoBV.phot']#,
            #'/n/home12/sgossage/match2.6_updated/MIST/Hyades/photometry/hyades_kopytova16_2MASSJK.phot']
filters = [('Tycho_B','Tycho_V')]#, ('2MASS_J', '2MASS_Ks')]
pgc.compare_iso(fehs, rots, ages, filters, dataf=datapath, dmod=[3.36], ebv = [0.001], ylim=[8,3], xlim=[-0.2,1.0])
img = mpimg.imread(os.path.join(os.getcwd(), 'plots', 'IsoCMD_comparison.png'))
plt.figure(figsize=(24,14))
plt.imshow(img)
plt.axis('off')
# Out:
# Extending option: gravdark_on = False to all grids.
#
#
# The created .iso file, /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.24_afe_p0.0_vvcrit0.5_interp.iso, has age range: 7.000000 to 10.000000 in log10 age.
#
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.24_afe_p0.0_vvcrit0.5_interp.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.24_afe_p0.0_vvcrit0.5_interp.iso.cmd
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.15_afe_p0.0_vvcrit0.5/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.5_full.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/feh_p0.15_afe_p0.0_vvcrit0.5/isochrones/MIST_v1.0_feh_p0.15_afe_p0.0_vvcrit0.5_full.iso.cmd
#
# ...

# %% [markdown]
# # Hyades 2MASSJK

# %%
rots = [0.6]
num_isos=len(rots)
fehs = [0.09]
ages = [8.63]
datapath = ['/n/home12/sgossage/match2.6_updated/MIST/Hyades/photometry/hyades_goldman13_2MASSJK.phot']#,
            #'/n/home12/sgossage/match2.6_updated/MIST/Hyades/photometry/hyades_kopytova16_2MASSJK.phot']
filters = [('2MASS_J', '2MASS_Ks')]
pgc.compare_iso(fehs, rots, ages, filters, dataf=datapath, dmod=[3.36], ebv = [0.001], ylim=[8,0], xlim=[-0.5,2.0], griddx=0.05, griddy=0.15)
img = mpimg.imread(os.path.join(os.getcwd(), 'plots', 'IsoCMD_comparison.png'))
plt.figure(figsize=(24,14))
plt.imshow(img)
plt.axis('off')
# Out:
# The created .iso file, /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.09_afe_p0.0_vvcrit0.6_interp.iso, has age range: 7.000000 to 10.000000 in log10 age.
#
#
# Creating .cmd file from /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.09_afe_p0.0_vvcrit0.6_interp.iso (log10 age range 7.000000 to 10.000000)...
#
# Reading in: /n/conroyfs1/sgossage/MIST_grids/MIST_v1.0/output/interpolations/MIST_v1.0_feh_p0.09_afe_p0.0_vvcrit0.6_interp.iso.cmd
# (-0.5, 3599.5, 2399.5, -0.5)

# %%
plt.clf()

# %%
plt.colormaps()
# Out:
# [u'Accent',
#  u'Accent_r',
#  u'Blues',
#  u'Blues_r',
#  u'BrBG',
#  u'BrBG_r',
#  u'BuGn',
#  u'BuGn_r',
#  u'BuPu',
#  u'BuPu_r',
#  u'CMRmap',
#  u'CMRmap_r',
#  u'Dark2',
#  u'Dark2_r',
#  u'GnBu',
#  u'GnBu_r',
#  u'Greens',
#  u'Greens_r',
#  u'Greys',
#  u'Greys_r',
#  u'OrRd',
#  u'OrRd_r',
#  u'Oranges',
#  u'Oranges_r',
#  u'PRGn',
#  u'PRGn_r',
#  u'Paired',
#  u'Paired_r',
#  u'Pastel1',
#  u'Pastel1_r',
#  u'Pastel2',
#  u'Pastel2_r',
#  u'PiYG',
#  u'PiYG_r',
#  u'PuBu',
#  u'PuBuGn',
#  u'PuBuGn_r',
#  u'PuBu_r',
#  u'PuOr',
#  u'PuOr_r',
#  u'PuRd',
#  u'PuRd_r',
#  u'Purples',
#  u'Purples_r',
#  u'RdBu',
#  u'RdBu_r',
#  u'RdGy',
#  u'RdGy_r',
#  u'RdPu',
#  u'RdPu_r',
#  u'RdYlBu',
#  u'RdYlBu_r',
#  u'RdYlGn',
#  u'RdYlGn_r',
#  u'Reds',
#  u'Reds_r',
#  u'Set1',
#  u'Set1_r',
#  u'Set2',
#  u'Set2_r',
#  u'Set3',
#  u'Set3_r',
#  u'Spectral',
#  u'Spectral_r',
#  u'Wistia',
#  u'Wistia_r',
#  u'YlGn',
#  u'YlGnBu',
#  u'YlGnBu_r',
#  u'YlGn_r',
#  u'YlOrBr',
# ...
